# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix
from sklearn.svm import SVC
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import classification_report

# %%
data = pd.read_csv('heart.csv')
data.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
#
#    ca  thal  target
# 0   0     1       1
# 1   0     2       1
# 2   0     2       1
# 3   0     2       1
# 4   0     2       1

# %%
X = data.iloc[:, :-1].values
y = data.iloc[:, 13].values

# %%
X_train, X_test, y_train, y_test =train_test_split(X , y, test_size= 0.3, random_state = 0)
tuned_parameters = [{'kernel': ['rbf'], 'gamma': [1e-3, 1e-4],
                     'C': range(1,10000,100)},
                    {'kernel': ['linear'], 'C': range(1,1000,10)}]
scores = ['precision', 'recall']
for score in scores:
    print("# Score: %s" % score)
    print()
    clf = GridSearchCV(SVC(), tuned_parameters, cv=5,
                       scoring='%s_macro' % score, n_jobs=3)
    clf.fit(X_train, y_train)

    print()
    print(clf.best_params_)
    print()
    means = clf.cv_results_['mean_test_score']
    stds = clf.cv_results_['std_test_score']
    for mean, std, params in zip(means, stds, clf.cv_results_['params']):
        print("%0.3f (+/-%0.03f) for %r"
              % (mean, std * 2, params))
    print()

    print()
    y_true, y_pred = y_test, clf.predict(X_test)
    print(classification_report(y_true, y_pred))
    print()
# Out:
# # Score: precision
# /home/ahmad/anaconda3/lib/python3.7/site-packages/sklearn/model_selection/_search.py:841: DeprecationWarning: The default of the `iid` parameter will change from True to False in version 0.22 and will be removed in 0.24. This will change numeric results when test-set sizes are unequal.
#   DeprecationWarning)
# {'C': 481, 'kernel': 'linear'}
#
# 0.638 (+/-0.105) for {'C': 1, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.681 (+/-0.132) for {'C': 1, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.608 (+/-0.084) for {'C': 101, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.770 (+/-0.109) for {'C': 101, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.608 (+/-0.084) for {'C': 201, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.786 (+/-0.103) for {'C': 201, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.608 (+/-0.084) for {'C': 301, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.772 (+/-0.130) for {'C': 301, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.608 (+/-0.084) for {'C': 401, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.753 (+/-0.115) for {'C': 401, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.608 (+/-0.084) for {'C': 501, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.754 (+/-0.125) for {'C': 501, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.608 (+/-0.084) for {'C': 601, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.759 (+/-0.143) for {'C': 601, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.608 (+/-0.084) for {'C': 701, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.752 (+/-0.146) for {'C': 701, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.608 (+/-0.084) for {'C': 801, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.761 (+/-0.116) for {'C': 801, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.608 (+/-0.084) for {'C': 901, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.760 (+/-0.156) for {'C': 901, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.608 (+/-0.084) for {'C': 1001, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.760 (+/-0.156) for {'C': 1001, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.608 (+/-0.084) for {'C': 1101, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.756 (+/-0.152) for {'C': 1101, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.608 (+/-0.084) for {'C': 1201, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.749 (+/-0.154) for {'C': 1201, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.608 (+/-0.084) for {'C': 1301, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.744 (+/-0.163) for {'C': 1301, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.608 (+/-0.084) for {'C': 1401, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.739 (+/-0.159) for {'C': 1401, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.608 (+/-0.084) for {'C': 1501, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.734 (+/-0.146) for {'C': 1501, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.608 (+/-0.084) for {'C': 1601, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.727 (+/-0.162) for {'C': 1601, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.608 (+/-0.084) for {'C': 1701, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.714 (+/-0.162) for {'C': 1701, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.608 (+/-0.084) for {'C': 1801, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.710 (+/-0.166) for {'C': 1801, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.608 (+/-0.084) for {'C': 1901, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.706 (+/-0.178) for {'C': 1901, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.608 (+/-0.084) for {'C': 2001, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.708 (+/-0.197) for {'C': 2001, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.608 (+/-0.084) for {'C': 2101, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.708 (+/-0.197) for {'C': 2101, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.608 (+/-0.084) for {'C': 2201, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.708 (+/-0.197) for {'C': 2201, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.608 (+/-0.084) for {'C': 2301, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.712 (+/-0.224) for {'C': 2301, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.608 (+/-0.084) for {'C': 2401, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.708 (+/-0.190) for {'C': 2401, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.608 (+/-0.084) for {'C': 2501, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.705 (+/-0.169) for {'C': 2501, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.608 (+/-0.084) for {'C': 2601, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.705 (+/-0.159) for {'C': 2601, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.608 (+/-0.084) for {'C': 2701, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.705 (+/-0.159) for {'C': 2701, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.608 (+/-0.084) for {'C': 2801, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.699 (+/-0.158) for {'C': 2801, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.608 (+/-0.084) for {'C': 2901, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.708 (+/-0.142) for {'C': 2901, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.608 (+/-0.084) for {'C': 3001, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.714 (+/-0.141) for {'C': 3001, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.608 (+/-0.084) for {'C': 3101, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.718 (+/-0.143) for {'C': 3101, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.608 (+/-0.084) for {'C': 3201, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.722 (+/-0.146) for {'C': 3201, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.608 (+/-0.084) for {'C': 3301, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.726 (+/-0.132) for {'C': 3301, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.608 (+/-0.084) for {'C': 3401, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.722 (+/-0.131) for {'C': 3401, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.608 (+/-0.084) for {'C': 3501, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.722 (+/-0.131) for {'C': 3501, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.608 (+/-0.084) for {'C': 3601, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.717 (+/-0.127) for {'C': 3601, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.608 (+/-0.084) for {'C': 3701, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.717 (+/-0.127) for {'C': 3701, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.608 (+/-0.084) for {'C': 3801, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.717 (+/-0.127) for {'C': 3801, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.608 (+/-0.084) for {'C': 3901, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.712 (+/-0.133) for {'C': 3901, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.608 (+/-0.084) for {'C': 4001, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.711 (+/-0.153) for {'C': 4001, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.608 (+/-0.084) for {'C': 4101, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.716 (+/-0.156) for {'C': 4101, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.608 (+/-0.084) for {'C': 4201, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.716 (+/-0.156) for {'C': 4201, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.608 (+/-0.084) for {'C': 4301, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.711 (+/-0.166) for {'C': 4301, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.608 (+/-0.084) for {'C': 4401, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.711 (+/-0.166) for {'C': 4401, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.608 (+/-0.084) for {'C': 4501, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.707 (+/-0.155) for {'C': 4501, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.608 (+/-0.084) for {'C': 4601, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.712 (+/-0.144) for {'C': 4601, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.608 (+/-0.084) for {'C':
 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.828 (+/-0.038) for {'C': 1, 'kernel': 'linear'}
# 0.833 (+/-0.095) for {'C': 11, 'kernel': 'linear'}
# 0.823 (+/-0.100) for {'C': 21, 'kernel': 'linear'}
# 0.813 (+/-0.099) for {'C': 31, 'kernel': 'linear'}
# 0.822 (+/-0.093) for {'C': 41, 'kernel': 'linear'}
# 0.822 (+/-0.112) for {'C': 51, 'kernel': 'linear'}
# 0.823 (+/-0.103) for {'C': 61, 'kernel': 'linear'}
# 0.815 (+/-0.130) for {'C': 71, 'kernel': 'linear'}
# 0.812 (+/-0.158) for {'C': 81, 'kernel': 'linear'}
# 0.835 (+/-0.156) for {'C': 91, 'kernel': 'linear'}
# 0.829 (+/-0.157) for {'C': 101, 'kernel': 'linear'}
# 0.831 (+/-0.139) for {'C': 111, 'kernel': 'linear'}
# 0.826 (+/-0.123) for {'C': 121, 'kernel': 'linear'}
# 0.813 (+/-0.100) for {'C': 131, 'kernel': 'linear'}
# 0.812 (+/-0.103) for {'C': 141, 'kernel': 'linear'}
# 0.812 (+/-0.106) for {'C': 151, 'kernel': 'linear'}
# 0.806 (+/-0.089) for {'C': 161, 'kernel': 'linear'}
# 0.811 (+/-0.095) for {'C': 171, 'kernel': 'linear'}
# 0.812 (+/-0.096) for {'C': 181, 'kernel': 'linear'}
# 0.812 (+/-0.096) for {'C': 191, 'kernel': 'linear'}
# 0.817 (+/-0.105) for {'C': 201, 'kernel': 'linear'}
# 0.812 (+/-0.105) for {'C': 211, 'kernel': 'linear'}
# 0.789 (+/-0.093) for {'C': 221, 'kernel': 'linear'}
# 0.800 (+/-0.092) for {'C': 231, 'kernel': 'linear'}
# 0.809 (+/-0.094) for {'C': 241, 'kernel': 'linear'}
# 0.812 (+/-0.075) for {'C': 251, 'kernel': 'linear'}
# 0.814 (+/-0.076) for {'C': 261, 'kernel': 'linear'}
# 0.827 (+/-0.029) for {'C': 271, 'kernel': 'linear'}
# 0.825 (+/-0.070) for {'C': 281, 'kernel': 'linear'}
# 0.829 (+/-0.066) for {'C': 291, 'kernel': 'linear'}
# 0.823 (+/-0.070) for {'C': 301, 'kernel': 'linear'}
# 0.833 (+/-0.072) for {'C': 311, 'kernel': 'linear'}
# 0.826 (+/-0.066) for {'C': 321, 'kernel': 'linear'}
# 0.831 (+/-0.078) for {'C': 331, 'kernel': 'linear'}
# 0.829 (+/-0.066) for {'C': 341, 'kernel': 'linear'}
# 0.821 (+/-0.092) for {'C': 351, 'kernel': 'linear'}
# 0.817 (+/-0.096) for {'C': 361, 'kernel': 'linear'}
# 0.831 (+/-0.061) for {'C': 371, 'kernel': 'linear'}
# 0.823 (+/-0.079) for {'C': 381, 'kernel': 'linear'}
# 0.823 (+/-0.079) for {'C': 391, 'kernel': 'linear'}
# 0.828 (+/-0.094) for {'C': 401, 'kernel': 'linear'}
# 0.820 (+/-0.072) for {'C': 411, 'kernel': 'linear'}
# 0.828 (+/-0.094) for {'C': 421, 'kernel': 'linear'}
# 0.828 (+/-0.094) for {'C': 431, 'kernel': 'linear'}
# 0.828 (+/-0.094) for {'C': 441, 'kernel': 'linear'}
# 0.828 (+/-0.094) for {'C': 451, 'kernel': 'linear'}
# 0.828 (+/-0.094) for {'C': 461, 'kernel': 'linear'}
# 0.828 (+/-0.094) for {'C': 471, 'kernel': 'linear'}
# 0.837 (+/-0.084) for {'C': 481, 'kernel': 'linear'}
# 0.828 (+/-0.094) for {'C': 491, 'kernel': 'linear'}
# 0.828 (+/-0.094) for {'C': 501, 'kernel': 'linear'}
# 0.828 (+/-0.094) for {'C': 511, 'kernel': 'linear'}
# 0.837 (+/-0.084) for {'C': 521, 'kernel': 'linear'}
# 0.832 (+/-0.070) for {'C': 531, 'kernel': 'linear'}
# 0.832 (+/-0.070) for {'C': 541, 'kernel': 'linear'}
# 0.832 (+/-0.070) for {'C': 551, 'kernel': 'linear'}
# 0.823 (+/-0.079) for {'C': 561, 'kernel': 'linear'}
# 0.829 (+/-0.066) for {'C': 571, 'kernel': 'linear'}
# 0.832 (+/-0.070) for {'C': 581, 'kernel': 'linear'}
# 0.832 (+/-0.070) for {'C': 591, 'kernel': 'linear'}
# 0.823 (+/-0.079) for {'C': 601, 'kernel': 'linear'}
# 0.832 (+/-0.070) for {'C': 611, 'kernel': 'linear'}
# 0.832 (+/-0.070) for {'C': 621, 'kernel': 'linear'}
# 0.823 (+/-0.069) for {'C': 631, 'kernel': 'linear'}
# 0.823 (+/-0.079) for {'C': 641, 'kernel': 'linear'}
# 0.823 (+/-0.079) for {'C': 651, 'kernel': 'linear'}
# 0.823 (+/-0.079) for {'C': 661, 'kernel': 'linear'}
# 0.832 (+/-0.070) for {'C': 671, 'kernel': 'linear'}
# 0.832 (+/-0.070) for {'C': 681, 'kernel': 'linear'}
# 0.832 (+/-0.070) for {'C': 691, 'kernel': 'linear'}
# 0.833 (+/-0.072) for {'C': 701, 'kernel': 'linear'}
# 0.833 (+/-0.072) for {'C': 711, 'kernel': 'linear'}
# 0.823 (+/-0.079) for {'C': 721, 'kernel': 'linear'}
# 0.833 (+/-0.072) for {'C': 731, 'kernel': 'linear'}
# 0.833 (+/-0.072) for {'C': 741, 'kernel': 'linear'}
# 0.832 (+/-0.070) for {'C': 751, 'kernel': 'linear'}
# 0.823 (+/-0.079) for {'C': 761, 'kernel': 'linear'}
# 0.827 (+/-0.073) for {'C': 771, 'kernel': 'linear'}
# 0.827 (+/-0.073) for {'C': 781, 'kernel': 'linear'}
# 0.814 (+/-0.063) for {'C': 791, 'kernel': 'linear'}
# 0.827 (+/-0.073) for {'C': 801, 'kernel': 'linear'}
# 0.823 (+/-0.079) for {'C': 811, 'kernel': 'linear'}
# 0.823 (+/-0.079) for {'C': 821, 'kernel': 'linear'}
# 0.827 (+/-0.073) for {'C': 831, 'kernel': 'linear'}
# 0.827 (+/-0.073) for {'C': 841, 'kernel': 'linear'}
# 0.823 (+/-0.079) for {'C': 851, 'kernel': 'linear'}
# 0.823 (+/-0.079) for {'C': 861, 'kernel': 'linear'}
# 0.823 (+/-0.079) for {'C': 871, 'kernel': 'linear'}
# 0.828 (+/-0.075) for {'C': 881, 'kernel': 'linear'}
# 0.827 (+/-0.073) for {'C': 891, 'kernel': 'linear'}
# 0.824 (+/-0.082) for {'C': 901, 'kernel': 'linear'}
# 0.827 (+/-0.073) for {'C': 911, 'kernel': 'linear'}
# 0.827 (+/-0.073) for {'C': 921, 'kernel': 'linear'}
# 0.823 (+/-0.079) for {'C': 931, 'kernel': 'linear'}
# 0.823 (+/-0.079) for {'C': 941, 'kernel': 'linear'}
# 0.828 (+/-0.094) for {'C': 951, 'kernel': 'linear'}
# 0.828 (+/-0.094) for {'C': 961, 'kernel': 'linear'}
# 0.827 (+/-0.073) for {'C': 971, 'kernel': 'linear'}
# 0.824 (+/-0.082) for {'C': 981, 'kernel': 'linear'}
# 0.828 (+/-0.094) for {'C': 991, 'kernel': 'linear'}
#
#
#               precision    recall  f1-score   support
#
#            0       0.82      0.64      0.72        44
#            1       0.72      0.87      0.79        47
#
#    micro avg       0.76      0.76      0.76        91
#    macro avg       0.77      0.75      0.75        91
# weighted avg       0.77      0.76      0.75        91
#
#
# # Score: recall
